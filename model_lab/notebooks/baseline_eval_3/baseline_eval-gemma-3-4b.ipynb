# %%
# !pip install -q -U "transformers>=4.50.0" accelerate bitsandbytes datasets sentencepiece pandas textstat rouge-score bert-score sacrebleu matplotlib
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 92.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.1/555.1 kB 32.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 96.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 102.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 79.1 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.3 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.3 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.3 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.3 which is incompatible.

# %%
import gc
import torch
import pandas as pd
import matplotlib.pyplot as plt

from textstat import flesch_kincaid_grade, automated_readability_index
from rouge_score import rouge_scorer
from bert_score import score as bertscore_score

from transformers import AutoProcessor, Gemma3ForConditionalGeneration, BitsAndBytesConfig

# %%
# Hugging Face login.
# Some models require accepting the model license on Hugging Face first.
# In Colab: left sidebar → Secrets → add HF_TOKEN with your Hugging Face READ token.

from google.colab import userdata
from huggingface_hub import login

HF_TOKEN = userdata.get("HF_TOKEN")

if HF_TOKEN:
    login(token=HF_TOKEN)
    print("Logged in to Hugging Face.")
else:
    print("No HF_TOKEN found. If this model is gated, loading will fail until you add HF_TOKEN.")
# Out:
# Logged in to Hugging Face.

# %%
# Change this if your file name is different
DATA_PATH = "/content/pilot_20_baseline_eval.csv"

df = pd.read_csv(DATA_PATH)

print("Columns found:")
print(df.columns.tolist())
print("\nNumber of rows:", len(df))

df.head()
# Out:
# Columns found:
# ['example_id', 'act_name', 'section_id', 'unit_label', 'unit_type', 'page_start', 'source_text', 'has_modal', 'has_exception', 'has_numbers', 'has_roles', 'needs_context', 'bad_fragment', 'simple_text', 'split', 'notes', 'pilot_category', 'llama3.2_output', 'qwen3_output', 'mistral_output', 'gemma_output', 'flan_t5_output', 'bart_output']
#
# Number of rows: 20
#   example_id    act_name   section_id   unit_label     unit_type  page_start  \
# 0    SL00023  Penal Code   Section 22          NaN  section_body         NaN
# 1    SL00135  Penal Code  Section 100  explanation   explanation        30.0
# 2    SL00022  Penal Code   Section 20            4    subsection         8.0
# 3    SL00045  Penal Code   Section 35          NaN  section_body        11.0
# 4    SL00049  Penal Code   Section 37          NaN  section_body         NaN
#
#                                          source_text  has_modal  \
# 0  Whoever does anything with the intention of ca...          0
# 1  A person who. by willful misrepresentation or ...          0
# 2   A person is said to lose wrongfully when such...          0
# 3  When an offence is committed by means of sever...          0
# 4  A person is said to cause an effect 'voluntari...          0
#
#    has_exception  has_numbers  ...  \
# 0              0            1  ...
# 1              0            1  ...
# 2              0            1  ...
# 3              0            1  ...
# 4              0            1  ...
#
#                                          simple_text  split  notes  \
# 0  A person acts dishonestly if they intend to ca...  train    NaN
# 1  A person instigates an act if they deliberatel...  train    NaN
# 2  A person does not only lose property wrongfull...  train    NaN
# 3  f a crime is carried out through a series of s...  train    NaN
# 4  A person acts voluntarily if they meant to bri...  train    NaN
#
#   pilot_category llama3.2_output  qwen3_output mistral_output  gemma_output  \
# 0     definition             NaN           NaN            NaN           NaN
# 1     definition             NaN           NaN            NaN           NaN
# 2     definition             NaN           NaN            NaN           NaN
# 3     definition             NaN           NaN            NaN           NaN
# 4     definition             NaN           NaN            NaN           NaN
#
#    flan_t5_output  bart_output
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
#
# [5 rows x 23 columns]

# %%
# Required input columns
required_columns = ["source_text", "simple_text"]

missing = [col for col in required_columns if col not in df.columns]
if missing:
    raise ValueError(f"Missing required columns: {missing}")

print("Input CSV is valid.")
# Out:
# Input CSV is valid.

# %%
MODEL_NAME = "google/gemma-3-4b-it"
MODEL_LABEL = "Gemma 3 4B IT"

OUTPUT_COLUMN = "gemma_output"
FKGL_COLUMN = "gemma_fkgl"
ARI_COLUMN = "gemma_ari"
ROUGE_COLUMN = "gemma_rougeL"
BERTSCORE_COLUMN = "gemma_bertscore_f1"

# %%
columns_to_create = [
    FKGL_COLUMN,
    ARI_COLUMN,
    ROUGE_COLUMN,
    BERTSCORE_COLUMN
]

# Initialize numeric columns
for col in columns_to_create:
    if col not in df.columns:
        df[col] = None

# Ensure OUTPUT_COLUMN is of string type ('object' dtype in pandas)
# and fill any NaN values with empty strings.
if OUTPUT_COLUMN not in df.columns:
    # If it's a new column, create it with empty strings and 'object' dtype
    df[OUTPUT_COLUMN] = pd.Series([''] * len(df), index=df.index, dtype='object')
else:
    # If it already exists (e.g., loaded from CSV with NaN), ensure it's 'object' dtype
    # and fill any NaN values with empty strings to prevent float conversion issues.
    df[OUTPUT_COLUMN] = df[OUTPUT_COLUMN].astype('object').fillna('')

print("Model-specific columns are ready.")
# Out:
# Model-specific columns are ready.

# %%
processor = AutoProcessor.from_pretrained(MODEL_NAME, padding_side="left")

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True
)

model = Gemma3ForConditionalGeneration.from_pretrained(
    MODEL_NAME,
    quantization_config=bnb_config,
    device_map="auto",
    low_cpu_mem_usage=True
).eval()

print("Model loaded in 4-bit.")
print("CUDA available:", torch.cuda.is_available())
# Out:
# processor_config.json:   0%|          | 0.00/70.0 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Model loaded in 4-bit.
# CUDA available: True

# %%
MAX_SOURCE_TOKENS = 700  # headroom under MAX_INPUT_TOKENS for system/rule text + chat template overhead

def build_messages(source_text: str):
    # Truncate the source text itself (not the tokenized prompt) so a long provision
    # never eats into the system instructions/rules. Confirmed bug fix -- see review.md.
    src_ids = processor.tokenizer(source_text, add_special_tokens=False)["input_ids"]
    if len(src_ids) > MAX_SOURCE_TOKENS:
        src_ids = src_ids[:MAX_SOURCE_TOKENS]
        source_text = processor.tokenizer.decode(src_ids, skip_special_tokens=True)

    return [
        {
            "role": "system",
            "content": [{"type": "text", "text": "You are a careful legal simplification assistant."}]
        },
        {
            "role": "user",
            "content": [{
                "type": "text",
                "text": f"""Simplify the Sri Lankan legal provision below into plain English.

Rules:
- Preserve the legal meaning as closely as possible.
- Keep SHALL, MAY, SHALL NOT.
- Keep numbers, dates, fines, punishments, conditions, exceptions, and legal roles.
- Do not add examples, commentary, or legal advice.

Provision:
{source_text}

Plain English:"""
            }]
        }
    ]

# %%
MAX_INPUT_TOKENS = 1024
MAX_NEW_TOKENS = 192

def generate_output(source_text: str) -> str:
    messages = build_messages(source_text)

    inputs = processor.apply_chat_template(
        messages,
        add_generation_prompt=True,
        tokenize=True,
        return_dict=True,
        return_tensors="pt"
    )

    # Move tensors to the model device. Do NOT cast input_ids to bfloat16/float16.
    inputs = {k: v.to(model.device) for k, v in inputs.items()}

    # Source text is already capped in build_messages, so this only guards the
    # rare case where the fixed system+rules text pushes the total over budget.
    if inputs["input_ids"].shape[-1] > MAX_INPUT_TOKENS:
        inputs["input_ids"] = inputs["input_ids"][:, -MAX_INPUT_TOKENS:]
        if "attention_mask" in inputs:
            inputs["attention_mask"] = inputs["attention_mask"][:, -MAX_INPUT_TOKENS:]

    input_len = inputs["input_ids"].shape[-1]

    # Confirmed bug fix: Gemma's chat turns end with <end_of_turn> (id 106), not the
    # base <eos> (id 1). Overriding eos_token_id with only the base eos meant the
    # model could run past its real stop point and append trailing content. Stop on both.
    end_of_turn_id = processor.tokenizer.convert_tokens_to_ids("<end_of_turn>")

    with torch.inference_mode():
        outputs = model.generate(
            **inputs,
            max_new_tokens=MAX_NEW_TOKENS,
            do_sample=False,
            num_beams=1,
            use_cache=True,
            pad_token_id=processor.tokenizer.pad_token_id,
            eos_token_id=[processor.tokenizer.eos_token_id, end_of_turn_id]
        )

    generated_ids = outputs[0][input_len:]
    text = processor.decode(generated_ids, skip_special_tokens=True).strip()

    del inputs, outputs, generated_ids
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    return text

# %%
# Optional quick test.
# Keep this False when using Colab Free, because testing first generates extra outputs and wastes RAM/time.
RUN_QUICK_TEST = False

if RUN_QUICK_TEST:
    for i in range(min(1, len(df))):
        source = str(df.loc[i, "source_text"])
        gold = str(df.loc[i, "simple_text"]) if pd.notna(df.loc[i, "simple_text"]) else ""

        pred = generate_output(source)

        print("ROW:", i)
        print("\nSOURCE:\n", source)
        print("\nGOLD SIMPLE TEXT:\n", gold)
        print("\nMODEL OUTPUT:\n", pred)
        print("\n" + "=" * 100 + "\n")
else:
    print("Quick test skipped. Set RUN_QUICK_TEST=True if you want to test one row first.")
# Out:
# Quick test skipped. Set RUN_QUICK_TEST=True if you want to test one row first.

# %%
# RAM-safe generation loop with checkpoint saving.
# This saves after every row, so if Colab crashes you can rerun and continue.
import os

CHECKPOINT_PATH = "/content/gemma_generation_checkpoint.csv"

if os.path.exists(CHECKPOINT_PATH):
    checkpoint_df = pd.read_csv(CHECKPOINT_PATH)
    if OUTPUT_COLUMN in checkpoint_df.columns and len(checkpoint_df) == len(df):
        # Ensure the column from checkpoint is also of object type and fill NaNs
        df[OUTPUT_COLUMN] = checkpoint_df[OUTPUT_COLUMN].astype('object').fillna('')
        print(f"Loaded existing checkpoint: {CHECKPOINT_PATH}")
    else:
        print("Checkpoint found but does not match this dataset. Starting fresh.")
else:
    print("No checkpoint found. Starting fresh.")

for idx, text in df["source_text"].fillna("").astype(str).items():
    existing = df.loc[idx, OUTPUT_COLUMN]

    if isinstance(existing, str) and existing.strip():
        print(f"Skipping row {idx + 1}/{len(df)} - already generated")
        continue

    pred = generate_output(text)
    df.loc[idx, OUTPUT_COLUMN] = pred

    # Save after every row
    df.to_csv(CHECKPOINT_PATH, index=False)
    print(f"Done {idx + 1}/{len(df)} - checkpoint saved")

    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

print("Generation complete.")
# Out:
# [transformers] Deprecated: `processor.image_token` will switch from returning `tokenizer.image_token` to `tokenizer.boi_token` in v5.11.
# No checkpoint found. Starting fresh.
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 1/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 2/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 3/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 4/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 5/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 6/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 7/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 8/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 9/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 10/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 11/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 12/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 13/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 14/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 15/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 16/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 17/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 18/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 19/20 - checkpoint saved
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Done 20/20 - checkpoint saved
# Generation complete.

# %%
def safe_fkgl(text):
    text = str(text).strip()
    if not text:
        return None
    try:
        return float(flesch_kincaid_grade(text))
    except Exception:
        return None

def safe_ari(text):
    text = str(text).strip()
    if not text:
        return None
    try:
        return float(automated_readability_index(text))
    except Exception:
        return None

df[FKGL_COLUMN] = df[OUTPUT_COLUMN].apply(safe_fkgl)
df[ARI_COLUMN] = df[OUTPUT_COLUMN].apply(safe_ari)

df[[OUTPUT_COLUMN, FKGL_COLUMN, ARI_COLUMN]].head()
# Out:
#                                         gemma_output  gemma_fkgl  gemma_ari
# 0  If someone does something with the intention o...   14.040000  17.301000
# 1  A person who, through intentional deception or...   18.116667  20.512500
# 2  A person is considered to have lost something ...   14.928000  16.504000
# 3  If a crime is committed through several action...   16.802500  18.414375
# 4  A person is considered to cause an effect if t...   11.843333  13.509000

# %%
# ROUGE-L against human gold simplification
scorer = rouge_scorer.RougeScorer(["rougeL"], use_stemmer=True)

rouge_scores = []

for pred, ref in zip(df[OUTPUT_COLUMN].fillna("").astype(str), df["simple_text"].fillna("").astype(str)):
    pred = pred.strip()
    ref = ref.strip()

    if not pred or not ref:
        rouge_scores.append(None)
    else:
        score = scorer.score(ref, pred)
        rouge_scores.append(float(score["rougeL"].fmeasure))

df[ROUGE_COLUMN] = rouge_scores

df[[OUTPUT_COLUMN, "simple_text", ROUGE_COLUMN]].head()
# Out:
#                                         gemma_output  \
# 0  If someone does something with the intention o...
# 1  A person who, through intentional deception or...
# 2  A person is considered to have lost something ...
# 3  If a crime is committed through several action...
# 4  A person is considered to cause an effect if t...
#
#                                          simple_text  gemma_rougeL
# 0  A person acts dishonestly if they intend to ca...      0.051282
# 1  A person instigates an act if they deliberatel...      0.376812
# 2  A person does not only lose property wrongfull...      0.241379
# 3  f a crime is carried out through a series of s...      0.523077
# 4  A person acts voluntarily if they meant to bri...      0.352941

# %%
# BERTScore against human gold simplification.
# IMPORTANT: unload the LLM before BERTScore. BERTScore loads another transformer model.
try:
    del model
except NameError:
    pass

try:
    del tokenizer
except NameError:
    pass

try:
    del processor
except NameError:
    pass

gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()

preds = df[OUTPUT_COLUMN].fillna("").astype(str).tolist()
refs = df["simple_text"].fillna("").astype(str).tolist()

valid_indices = []
valid_preds = []
valid_refs = []

for i, (pred, ref) in enumerate(zip(preds, refs)):
    if pred.strip() and ref.strip():
        valid_indices.append(i)
        valid_preds.append(pred)
        valid_refs.append(ref)

bert_f1_scores = [None] * len(df)

if valid_preds:
    P, R, F1 = bertscore_score(
        valid_preds,
        valid_refs,
        lang="en",
        batch_size=4,
        verbose=False,
        device="cuda" if torch.cuda.is_available() else "cpu"
    )
    for idx, score in zip(valid_indices, F1):
        bert_f1_scores[idx] = float(score)

df[BERTSCORE_COLUMN] = bert_f1_scores

df[[OUTPUT_COLUMN, "simple_text", BERTSCORE_COLUMN]].head()
# Out:
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# [transformers] RobertaModel LOAD REPORT from: roberta-large
# Key                       | Status     |
# --------------------------+------------+-
# lm_head.dense.weight      | UNEXPECTED |
# lm_head.bias              | UNEXPECTED |
# lm_head.layer_norm.bias   | UNEXPECTED |
# lm_head.layer_norm.weight | UNEXPECTED |
# lm_head.dense.bias        | UNEXPECTED |
# pooler.dense.weight       | MISSING    |
# pooler.dense.bias         | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#                                         gemma_output  \
# 0  If someone does something with the intention o...
# 1  A person who, through intentional deception or...
# 2  A person is considered to have lost something ...
# 3  If a crime is committed through several action...
# 4  A person is considered to cause an effect if t...
#
#                                          simple_text  gemma_bertscore_f1
# 0  A person acts dishonestly if they intend to ca...            0.907484
# 1  A person instigates an act if they deliberatel...            0.907177
# 2  A person does not only lose property wrongfull...            0.910211
# 3  f a crime is carried out through a series of s...            0.935410
# 4  A person acts voluntarily if they meant to bri...            0.899076

# %%
# Create a clean result table without dataset-analysis metadata columns
keep_cols = []

# Keep useful identifiers only if they exist
for col in ["example_id", "act_name", "section_id", "unit_type", "split"]:
    if col in df.columns:
        keep_cols.append(col)

keep_cols += [
    "source_text",
    "simple_text",
    OUTPUT_COLUMN,
    FKGL_COLUMN,
    ARI_COLUMN,
    ROUGE_COLUMN,
    BERTSCORE_COLUMN
]

result_df = df[keep_cols].copy()

print("Clean result table preview:")
result_df.head(10)
# Out:
# Clean result table preview:
#   example_id    act_name   section_id     unit_type  split  \
# 0    SL00023  Penal Code   Section 22  section_body  train
# 1    SL00135  Penal Code  Section 100   explanation  train
# 2    SL00022  Penal Code   Section 20    subsection  train
# 3    SL00045  Penal Code   Section 35  section_body  train
# 4    SL00049  Penal Code   Section 37  section_body  train
# 5    SL00073  Penal Code   Section 54  section_body  train
# 6    SL00075  Penal Code   Section 56  section_body  train
# 7    SL00077  Penal Code   Section 57  section_body  train
# 8    SL00160  Penal Code  Section 107  section_body  train
# 9    SL00166  Penal Code  Section 110  section_body  train
#
#                                          source_text  \
# 0  Whoever does anything with the intention of ca...
# 1  A person who. by willful misrepresentation or ...
# 2   A person is said to lose wrongfully when such...
# 3  When an offence is committed by means of sever...
# 4  A person is said to cause an effect 'voluntari...
# 5  Sentence of death shall not be pronounced on o...
# 6  In every case in which a person is convicted o...
# 7  No female shall in any case be punished with w...
# 8  Whenever any person who, if absent, would be l...
# 9  Whoever abets the commission of an offence by ...
#
#                                          simple_text  \
# 0  A person acts dishonestly if they intend to ca...
# 1  A person instigates an act if they deliberatel...
# 2  A person does not only lose property wrongfull...
# 3  f a crime is carried out through a series of s...
# 4  A person acts voluntarily if they meant to bri...
# 5  A pregnant woman cannot be sentenced to death....
# 6  If someone is convicted of a crime where all t...
# 7  Women cannot be punished by whipping under any...
# 8  If a person encouraged or helped someone commi...
# 9  If a person encourages or helps a crime that i...
#
#                                         gemma_output  gemma_fkgl  gemma_ari  \
# 0  If someone does something with the intention o...   14.040000  17.301000
# 1  A person who, through intentional deception or...   18.116667  20.512500
# 2  A person is considered to have lost something ...   14.928000  16.504000
# 3  If a crime is committed through several action...   16.802500  18.414375
# 4  A person is considered to cause an effect if t...   11.843333  13.509000
# 5  The court shall not impose a death sentence on...    8.161569   8.311176
# 6  In any case where someone is found guilty of a...   13.611538  15.029423
# 7  No woman shall be punished by whipping. Also, ...    6.298333   7.138750
# 8  If a person who would otherwise be held respon...   16.065000  18.120000
# 9  If someone helps to commit a crime that is don...   14.445789  16.410000
#
#    gemma_rougeL  gemma_bertscore_f1
# 0      0.051282            0.907484
# 1      0.376812            0.907177
# 2      0.241379            0.910211
# 3      0.523077            0.935410
# 4      0.352941            0.899076
# 5      0.532110            0.942366
# 6      0.351852            0.913845
# 7      0.518519            0.942115
# 8      0.441176            0.917304
# 9      0.675000            0.937080

# %%
def avg_of_column(dataframe, col_name):
    vals = pd.to_numeric(dataframe[col_name], errors="coerce")
    vals = vals.dropna()
    return None if len(vals) == 0 else round(float(vals.mean()), 3)

summary = {
    "Model": MODEL_LABEL,
    "Rows": len(result_df),
    "Avg FKGL": avg_of_column(result_df, FKGL_COLUMN),
    "Avg ARI": avg_of_column(result_df, ARI_COLUMN),
    "Avg ROUGE-L": avg_of_column(result_df, ROUGE_COLUMN),
    "Avg BERTScore F1": avg_of_column(result_df, BERTSCORE_COLUMN),
}

summary_df = pd.DataFrame([summary])
summary_df
# Out:
#            Model  Rows  Avg FKGL  Avg ARI  Avg ROUGE-L  Avg BERTScore F1
# 0  Gemma 3 4B IT    20    15.793   17.689        0.439             0.924

# %%
OUT_PATH = "/content/pilot_20_baseline_eval_with_gemma_checked_clean.csv"
result_df.to_csv(OUT_PATH, index=False)

print(f"Saved clean result CSV to: {OUT_PATH}")
# Out:
# Saved clean result CSV to: /content/pilot_20_baseline_eval_with_gemma_checked_clean.csv

# %%
fig, ax = plt.subplots(figsize=(10, 2.8))
ax.axis("off")

plt.title(f"{MODEL_LABEL} - Baseline Evaluation Summary", fontsize=14, pad=14)

table = ax.table(
    cellText=summary_df.values,
    colLabels=summary_df.columns,
    loc="center",
    cellLoc="center"
)

table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.6)

IMAGE_PATH = "/content/gemma_summary_table.png"
plt.savefig(IMAGE_PATH, bbox_inches="tight", dpi=200)
plt.show()

print(f"Saved summary table image to: {IMAGE_PATH}")
# Out:
# Saved summary table image to: /content/gemma_summary_table.png

# %%
# Optional: clear memory
for name in ["model", "tokenizer", "processor"]:
    if name in globals():
        del globals()[name]

gc.collect()

if torch.cuda.is_available():
    torch.cuda.empty_cache()

print("Memory cleared.")
# Out:
# Memory cleared.
